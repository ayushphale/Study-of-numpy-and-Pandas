# %% [markdown]
# #**Experiment-9**
# ###Study of Pandas Library
# ####Batch- ENTC A2
# #### Ayush Phale PRN  25070123028

# %%
#Introduction to Pandas
# Pandas: Panel Data
''' Used for:
EDA
Structed data
Data cleaning'''

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#Create DataFrame
data={
    "Name":["A","B","C"],
    "Marks":[85,90,78]
}
df=pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
#Find the structure of  the DataFrame
df.shape
# Out:
# (3, 2)

# %%
#Dimension of  the DataFrame
df.ndim    #will always give no of columns
# Out:
# 2

# %%
#size of the DataFrame
df.size
# Out:
# 6

# %%
#Display Column Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#check Data types of each columns
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access individual Column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
#Access Specific Row
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
#Add a new column
df["Grade"]=["First CLass","Distinction","Second Class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     85   First CLass
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#Update Data in DataFrame
#Change marks of student to 88
df.loc[0,"Marks"] = 88
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First CLass
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#Delete a column
df.drop("Grade",axis=1,inplace=True)
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %%
#Perform Basic Statistical Analysis
mean1 = df["Marks"].mean()
mean1
# Out:
# np.float64(85.33333333333333)

# %%
min1 = df["Marks"].min()
min1
# Out:
# 78

# %%
max1 = df["Marks"].max()
max1
# Out:
# 90

# %%
#Appy condition(Filtering)
#Display students scoring more than 80
df[df["Marks"]>80]
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78
