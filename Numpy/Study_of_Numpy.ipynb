# %% [markdown]
# #Experiment No. 8
# ##Tools for EDA - Study of Numpy
# #### Ayush Phale PRN-25070123028
# ###### ENTC A2

# %%
#why numpy
#Faster than lisys
#Used for numerical computation
#Base for pandas

# %%
#Declaration of numpy
import numpy as np

a = np.array ([10,20,30,40])
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [4 5 6]]

# %%
##Dimension of Array
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
#Shape of Arrays
print(a.shape)
print(b.shape)
# Out:
# (4,)
# (2, 3)

# %%
#Data types of Arrays
print(a.dtype)
print(b.dtype)
# Out:
# int64
# int64

# %%
#Matrix Multiplication
print(np.zeros((2,3)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(np.zeros((3,3)))
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(np.ones((3,3)))
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
print(np.arange(1,10,2))
# Out:
# [1 3 5 7 9]

# %%
print(np.linspace(0,1,5))
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
c= a*2
d=a+5
print(c)
print(d)
# Out:
# [20 40 60 80]
# [15 25 35 45]

# %%
a+5
# Out:
# array([15, 25, 35, 45])

# %%
#Average
print(np.mean(a)) #With print command we get direct answer
# Out:
# 25.0

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.min(a)
# Out:
# np.int64(10)
